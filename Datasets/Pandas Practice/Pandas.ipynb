# %%
import pandas as pd
dummy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Feature1': ['A', 'C', 'E', 'G', 'I'],
        'Feature2': ['B', 'D', 'F', 'H', 'J']}
df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2'])
dummy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Feature1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature2': ['L', 'N', 'P', 'R', 'T']}
df2 = pd.DataFrame(dummy_data2, columns = ['id', 'Feature1', 'Feature2'])
df_join = pd.concat([df1, df2])
df_row_reindex = pd.concat([df1, df2], ignore_index=True)
df_row_reindex.tail()
# Out:
#   id Feature1 Feature2
# 8  7        Q        R
# 9  8        S        T

# %%
df_row_reindex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10 non-null     object
#  1   Feature1  10 non-null     object
#  2   Feature2  10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
df = df_row_reindex

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['id', 'Feature1', 'Feature2']

# %%
df.columns
# Out:
# Index(['id', 'Feature1', 'Feature2'], dtype='object')

# %%
df['Feature1'].unique()
# Out:
# array(['A', 'C', 'E', 'G', 'I', 'K', 'M', 'O', 'Q', 'S'], dtype=object)

# %%
df.Feature1.unique()
# Out:
# array(['A', 'C', 'E', 'G', 'I', 'K', 'M', 'O', 'Q', 'S'], dtype=object)

# %%
df
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J
# 5  1        K        L
# 6  2        M        N
# 7  6        O        P
# 8  7        Q        R
# 9  8        S        T

# %%
df.describe()
# Out:
#         id Feature1 Feature2
# count   10       10       10
# unique   8       10       10
# top      2        C        T
# freq     2        1        1

# %%
df.id.unique().shape
# Out:
# (8,)

# %%
df.Feature1.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
leads = pd.read_csv("LEADS-(2019-20).csv")
leads.head()
# Out:
#    Lead_ID First_name   Last_name          Full_name Gender Date_of_Birth  \
# 0  LI-5290    Queenie      Elgood     Queenie Elgood      F    27/03/2017
# 1  LI-0891     Larisa  O'Hoolahan  Larisa O'Hoolahan      F    29/01/1992
# 2  LI-0590     Anissa  Lafranconi  Anissa Lafranconi      F    21/10/2000
# 3  LI-9688   Giordano      Center    Giordano Center      M    10/03/2002
# 4  LI-6819    Ingunna    Bratcher   Ingunna Bratcher      F    16/02/2004
#
#    Product_name  Product_ID Account_Created_Date          Product_Category
# 0  "Kits Focal"  JS-1472-dn           24/10/2019                 "Kitchen"
# 1      "Ultron"  BM-4239-td           13/07/2020  "Science and Technology"
# 2      "Jarvis"  BM-8148-qv           23/09/2019           "Art and Craft"
# 3      "Jarvis"  JS-0086-or           08/07/2020                 "Kitchen"
# 4      "Jarvis"  RP-8216-hw           19/03/2020                 "Kitchen"

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               1000 non-null   object
#  1   First_name            1000 non-null   object
#  2   Last_name             1000 non-null   object
#  3   Full_name             1000 non-null   object
#  4   Gender                1000 non-null   object
#  5   Date_of_Birth         1000 non-null   object
#  6   Product_name          1000 non-null   object
#  7   Product_ID            1000 non-null   object
#  8   Account_Created_Date  1000 non-null   object
#  9   Product_Category      1000 non-null   object
# dtypes: object(10)
# memory usage: 78.2+ KB

# %%
leads.Account_Created_Date = pd.to_datetime(leads.Account_Created_Date)

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               1000 non-null   object
#  1   First_name            1000 non-null   object
#  2   Last_name             1000 non-null   object
#  3   Full_name             1000 non-null   object
#  4   Gender                1000 non-null   object
#  5   Date_of_Birth         1000 non-null   object
#  6   Product_name          1000 non-null   object
#  7   Product_ID            1000 non-null   object
#  8   Account_Created_Date  1000 non-null   datetime64[ns]
#  9   Product_Category      1000 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 78.2+ KB

# %%
leads['test_date'] = leads.Account_Created_Date.dt.date

# %%
leads.head()
# Out:
#    Lead_ID First_name   Last_name          Full_name Gender Date_of_Birth  \
# 0  LI-5290    Queenie      Elgood     Queenie Elgood      F    27/03/2017
# 1  LI-0891     Larisa  O'Hoolahan  Larisa O'Hoolahan      F    29/01/1992
# 2  LI-0590     Anissa  Lafranconi  Anissa Lafranconi      F    21/10/2000
# 3  LI-9688   Giordano      Center    Giordano Center      M    10/03/2002
# 4  LI-6819    Ingunna    Bratcher   Ingunna Bratcher      F    16/02/2004
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# 0  "Kits Focal"  JS-1472-dn           2019-10-24                 "Kitchen"
# 1      "Ultron"  BM-4239-td           2020-07-13  "Science and Technology"
# 2      "Jarvis"  BM-8148-qv           2019-09-23           "Art and Craft"
# 3      "Jarvis"  JS-0086-or           2020-08-07                 "Kitchen"
# 4      "Jarvis"  RP-8216-hw           2020-03-19                 "Kitchen"
#
#     test_date
# 0  2019-10-24
# 1  2020-07-13
# 2  2019-09-23
# ...

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               1000 non-null   object
#  1   First_name            1000 non-null   object
#  2   Last_name             1000 non-null   object
#  3   Full_name             1000 non-null   object
#  4   Gender                1000 non-null   object
#  5   Date_of_Birth         1000 non-null   object
#  6   Product_name          1000 non-null   object
#  7   Product_ID            1000 non-null   object
#  8   Account_Created_Date  1000 non-null   datetime64[ns]
#  9   Product_Category      1000 non-null   object
#  10  test_date             1000 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 86.1+ KB

# %%
leads.Date_of_Birth = pd.to_datetime(leads.Date_of_Birth)
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 877 to 529
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               1000 non-null   object
#  1   First_name            1000 non-null   object
#  2   Last_name             1000 non-null   object
#  3   Full_name             1000 non-null   object
#  4   Gender                1000 non-null   object
#  5   Date_of_Birth         1000 non-null   datetime64[ns]
#  6   Product_name          1000 non-null   object
#  7   Product_ID            1000 non-null   object
#  8   Account_Created_Date  1000 non-null   datetime64[ns]
#  9   Product_Category      1000 non-null   object
#  10  test_date             1000 non-null   object
# dtypes: datetime64[ns](2), object(9)
# memory usage: 93.8+ KB

# %%
leads.sort_values(by = ['Date_of_Birth', 
                               'Account_Created_Date'], 
                         inplace=True,
                         ascending=True, 
                         axis=0
                        )

# %%
leads.head(10)
# Out:
#      Lead_ID First_name    Last_name           Full_name Gender Date_of_Birth  \
# 531  LI-0017     Dickie         Hupe         Dickie Hupe      M    1990-01-12
# 201  LI-5592       Case        Meyer          Case Meyer      M    1990-01-12
# 126  LI-2601    Roselia      Burkart     Roselia Burkart      F    1990-02-12
# 84   LI-6778      Pearl     Domesday      Pearl Domesday      F    1990-03-11
# 791  LI-0008    Giffard     Bottrell    Giffard Bottrell      M    1990-08-10
# 251  LI-3285    Gearard     McGoogan    Gearard McGoogan      M    1990-08-10
# 398  LI-7839     Anatol  Lethebridge  Anatol Lethebridge      M    1990-10-12
# 64   LI-3819       Tera        Heugh          Tera Heugh      F    1990-10-12
# 420  LI-2823      Ashby    Rubenfeld     Ashby Rubenfeld      M    1990-10-13
# 212  LI-2802   Granthem        Sacks      Granthem Sacks      M    1990-10-20
#
#      Product_name  Product_ID Account_Created_Date          Product_Category  \
# ...

# %%
leads.reset_index(drop=True, inplace=True)

# %%
leads.head(10)
# Out:
#    Lead_ID First_name    Last_name           Full_name Gender Date_of_Birth  \
# 0  LI-0017     Dickie         Hupe         Dickie Hupe      M    1990-01-12
# 1  LI-5592       Case        Meyer          Case Meyer      M    1990-01-12
# 2  LI-2601    Roselia      Burkart     Roselia Burkart      F    1990-02-12
# 3  LI-6778      Pearl     Domesday      Pearl Domesday      F    1990-03-11
# 4  LI-0008    Giffard     Bottrell    Giffard Bottrell      M    1990-08-10
# 5  LI-3285    Gearard     McGoogan    Gearard McGoogan      M    1990-08-10
# 6  LI-7839     Anatol  Lethebridge  Anatol Lethebridge      M    1990-10-12
# 7  LI-3819       Tera        Heugh          Tera Heugh      F    1990-10-12
# 8  LI-2823      Ashby    Rubenfeld     Ashby Rubenfeld      M    1990-10-13
# 9  LI-2802   Granthem        Sacks      Granthem Sacks      M    1990-10-20
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# ...

# %%
leads.drop(['test_date'], axis=1, inplace=True)

# %%
leads.head(10)
# Out:
#    Lead_ID First_name    Last_name           Full_name Gender Date_of_Birth  \
# 0  LI-0017     Dickie         Hupe         Dickie Hupe      M    1990-01-12
# 1  LI-5592       Case        Meyer          Case Meyer      M    1990-01-12
# 2  LI-2601    Roselia      Burkart     Roselia Burkart      F    1990-02-12
# 3  LI-6778      Pearl     Domesday      Pearl Domesday      F    1990-03-11
# 4  LI-0008    Giffard     Bottrell    Giffard Bottrell      M    1990-08-10
# 5  LI-3285    Gearard     McGoogan    Gearard McGoogan      M    1990-08-10
# 6  LI-7839     Anatol  Lethebridge  Anatol Lethebridge      M    1990-10-12
# 7  LI-3819       Tera        Heugh          Tera Heugh      F    1990-10-12
# 8  LI-2823      Ashby    Rubenfeld     Ashby Rubenfeld      M    1990-10-13
# 9  LI-2802   Granthem        Sacks      Granthem Sacks      M    1990-10-20
#
#    Product_name  Product_ID Account_Created_Date          Product_Category
# ...

# %%
def printNullValues(df):
    total = df.isnull().sum().sort_values(ascending = False)
    total = total[df.isnull().sum().sort_values(ascending = False) != 0]
    percent = total * 100 / len(df)
    percent = percent[df.isnull().sum().sort_values(ascending = False) != 0]
    concat = pd.concat([total, percent], axis=1, keys=['Total','Percent'])
    print (concat)
    print ( "-------------")
    
printNullValues(leads)
# Out:
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []
# -------------

# %%
ultron_ke_mentions = leads[leads.Product_name == '"Ultron"']

# %%
ultron_ke_mentions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 1 to 986
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               229 non-null    object
#  1   First_name            229 non-null    object
#  2   Last_name             229 non-null    object
#  3   Full_name             229 non-null    object
#  4   Gender                229 non-null    object
#  5   Date_of_Birth         229 non-null    datetime64[ns]
#  6   Product_name          229 non-null    object
#  7   Product_ID            229 non-null    object
#  8   Account_Created_Date  229 non-null    datetime64[ns]
#  9   Product_Category      229 non-null    object
# dtypes: datetime64[ns](2), object(8)
# memory usage: 19.7+ KB

# %%
ultron_ke_mentions[ultron_ke_mentions.Account_Created_Date.dt.year == 2020]
# Out:
#      Lead_ID First_name     Last_name             Full_name Gender  \
# 1    LI-5592       Case         Meyer            Case Meyer      M
# 2    LI-2601    Roselia       Burkart       Roselia Burkart      F
# 3    LI-6778      Pearl      Domesday        Pearl Domesday      F
# 4    LI-0008    Giffard      Bottrell      Giffard Bottrell      M
# 5    LI-3285    Gearard      McGoogan      Gearard McGoogan      M
# ..       ...        ...           ...                   ...    ...
# 963  LI-4949    Michael  Brennenstuhl  Michael Brennenstuhl      M
# 964  LI-0830  Anneliese       Redmile     Anneliese Redmile      F
# 971  LI-2727      Alley          Artz            Alley Artz      M
# 979  LI-3843     Sibley      Surgison       Sibley Surgison      F
# 981  LI-7062      Robby        Corker          Robby Corker      M
#
#     Date_of_Birth Product_name  Product_ID Account_Created_Date  \
# 1      1990-01-12     "Ultron"  BM-3108-tn           2020-03-09
# ...

# %%
ultron_ke_mentions[(ultron_ke_mentions.Account_Created_Date.dt.year == 2020) & (ultron_ke_mentions.Gender == 'M')]
# Out:
#      Lead_ID First_name     Last_name             Full_name Gender  \
# 1    LI-5592       Case         Meyer            Case Meyer      M
# 4    LI-0008    Giffard      Bottrell      Giffard Bottrell      M
# 5    LI-3285    Gearard      McGoogan      Gearard McGoogan      M
# 8    LI-2823      Ashby     Rubenfeld       Ashby Rubenfeld      M
# 14   LI-7861       Ezri         Joffe            Ezri Joffe      M
# ..       ...        ...           ...                   ...    ...
# 935  LI-9604      Adham       Tallant         Adham Tallant      M
# 957  LI-1225     Collin         Cotty          Collin Cotty      M
# 963  LI-4949    Michael  Brennenstuhl  Michael Brennenstuhl      M
# 971  LI-2727      Alley          Artz            Alley Artz      M
# 981  LI-7062      Robby        Corker          Robby Corker      M
#
#     Date_of_Birth Product_name  Product_ID Account_Created_Date  \
# 1      1990-01-12     "Ultron"  BM-3108-tn           2020-03-09
# ...

# %%
ultron_ke_mentions['Age'] = pd.to_datetime('2020-11-09') - ultron_ke_mentions.Date_of_Birth
# Out:
# <ipython-input-95-00afda69acdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultron_ke_mentions['Age'] = pd.to_datetime('2020-11-09') - ultron_ke_mentions.Date_of_Birth

# %%
ultron_ke_mentions.head(10)
# Out:
#     Lead_ID First_name  Last_name         Full_name Gender Date_of_Birth  \
# 1   LI-5592       Case      Meyer        Case Meyer      M    1990-01-12
# 2   LI-2601    Roselia    Burkart   Roselia Burkart      F    1990-02-12
# 3   LI-6778      Pearl   Domesday    Pearl Domesday      F    1990-03-11
# 4   LI-0008    Giffard   Bottrell  Giffard Bottrell      M    1990-08-10
# 5   LI-3285    Gearard   McGoogan  Gearard McGoogan      M    1990-08-10
# 8   LI-2823      Ashby  Rubenfeld   Ashby Rubenfeld      M    1990-10-13
# 14  LI-7861       Ezri      Joffe        Ezri Joffe      M    1990-11-26
# 24  LI-1641    Saunder       Pllu      Saunder Pllu      M    1991-04-23
# 26  LI-8065   Filberto      Mosco    Filberto Mosco      M    1991-06-08
# 27  LI-5227     Andres    Woodham    Andres Woodham      M    1991-06-23
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# 1      "Ultron"  BM-3108-tn           2020-03-09  "Science and Technology"
# ...

# %%
ultron_ke_mentions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 1 to 986
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Lead_ID               229 non-null    object
#  1   First_name            229 non-null    object
#  2   Last_name             229 non-null    object
#  3   Full_name             229 non-null    object
#  4   Gender                229 non-null    object
#  5   Date_of_Birth         229 non-null    datetime64[ns]
#  6   Product_name          229 non-null    object
#  7   Product_ID            229 non-null    object
#  8   Account_Created_Date  229 non-null    datetime64[ns]
#  9   Product_Category      229 non-null    object
#  10  Age_in_years          229 non-null    timedelta64[ns]
#  11  Age                   229 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), object(8), timedelta64[ns](2)
# memory usage: 23.3+ KB

# %%
ultron_ke_mentions['Age_in_years'] = ultron_ke_mentions.Age/(365*24*60*60)
# Out:
# <ipython-input-98-467de6a3e06b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ultron_ke_mentions['Age_in_years'] = ultron_ke_mentions.Age/(365*24*60*60)

# %%
ultron_ke_mentions.head(10)
# Out:
#     Lead_ID First_name  Last_name         Full_name Gender Date_of_Birth  \
# 1   LI-5592       Case      Meyer        Case Meyer      M    1990-01-12
# 2   LI-2601    Roselia    Burkart   Roselia Burkart      F    1990-02-12
# 3   LI-6778      Pearl   Domesday    Pearl Domesday      F    1990-03-11
# 4   LI-0008    Giffard   Bottrell  Giffard Bottrell      M    1990-08-10
# 5   LI-3285    Gearard   McGoogan  Gearard McGoogan      M    1990-08-10
# 8   LI-2823      Ashby  Rubenfeld   Ashby Rubenfeld      M    1990-10-13
# 14  LI-7861       Ezri      Joffe        Ezri Joffe      M    1990-11-26
# 24  LI-1641    Saunder       Pllu      Saunder Pllu      M    1991-04-23
# 26  LI-8065   Filberto      Mosco    Filberto Mosco      M    1991-06-08
# 27  LI-5227     Andres    Woodham    Andres Woodham      M    1991-06-23
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# 1      "Ultron"  BM-3108-tn           2020-03-09  "Science and Technology"
# ...

# %%
ultron_ke_mentions.drop(['Age'], inplace=True, axis=1)
# Out:
# c:\users\jaswinder singh\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ultron_ke_mentions.head(10)
# Out:
#     Lead_ID First_name  Last_name         Full_name Gender Date_of_Birth  \
# 1   LI-5592       Case      Meyer        Case Meyer      M    1990-01-12
# 2   LI-2601    Roselia    Burkart   Roselia Burkart      F    1990-02-12
# 3   LI-6778      Pearl   Domesday    Pearl Domesday      F    1990-03-11
# 4   LI-0008    Giffard   Bottrell  Giffard Bottrell      M    1990-08-10
# 5   LI-3285    Gearard   McGoogan  Gearard McGoogan      M    1990-08-10
# 8   LI-2823      Ashby  Rubenfeld   Ashby Rubenfeld      M    1990-10-13
# 14  LI-7861       Ezri      Joffe        Ezri Joffe      M    1990-11-26
# 24  LI-1641    Saunder       Pllu      Saunder Pllu      M    1991-04-23
# 26  LI-8065   Filberto      Mosco    Filberto Mosco      M    1991-06-08
# 27  LI-5227     Andres    Woodham    Andres Woodham      M    1991-06-23
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# 1      "Ultron"  BM-3108-tn           2020-03-09  "Science and Technology"
# ...

# %%
ultron_ke_mentions.rename(columns = {'Age_in_years':'faltu'
           }, 
     inplace = True)
# Out:
# c:\users\jaswinder singh\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
ultron_ke_mentions.head(10)
# Out:
#     Lead_ID First_name  Last_name         Full_name Gender Date_of_Birth  \
# 1   LI-5592       Case      Meyer        Case Meyer      M    1990-01-12
# 2   LI-2601    Roselia    Burkart   Roselia Burkart      F    1990-02-12
# 3   LI-6778      Pearl   Domesday    Pearl Domesday      F    1990-03-11
# 4   LI-0008    Giffard   Bottrell  Giffard Bottrell      M    1990-08-10
# 5   LI-3285    Gearard   McGoogan  Gearard McGoogan      M    1990-08-10
# 8   LI-2823      Ashby  Rubenfeld   Ashby Rubenfeld      M    1990-10-13
# 14  LI-7861       Ezri      Joffe        Ezri Joffe      M    1990-11-26
# 24  LI-1641    Saunder       Pllu      Saunder Pllu      M    1991-04-23
# 26  LI-8065   Filberto      Mosco    Filberto Mosco      M    1991-06-08
# 27  LI-5227     Andres    Woodham    Andres Woodham      M    1991-06-23
#
#    Product_name  Product_ID Account_Created_Date          Product_Category  \
# 1      "Ultron"  BM-3108-tn           2020-03-09  "Science and Technology"
# ...

# %%
ultron_ke_mentions.to_csv('CSV_hai_bro.csv', index=False)

#to an excel file
# ultron_ke_mentions.to_excel('Excel_hai_bro.xlsx', index=False)

# %%
pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\users\jaswinder' is not recognized as an internal or external command,
# operable program or batch file.
